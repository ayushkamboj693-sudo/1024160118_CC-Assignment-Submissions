# %% [markdown]
# Take your roll number. Extract its individual digits, and multiply each digit by 10 to form your list L (10 numbers in list now).
#
# Print L Add two numbers of your choice to L — one using append() and one using insert() at a specific position. Print L after each and explain in a comment what changed.
#
# Remove two elements from L — one using remove() and one using pop(). Print L after each.
#
# Sort L in ascending order using sort(), then descending order using sort(reverse=True). Print both.
#
# Use slicing to print the first three elements and the last three elements of L in a single line each. vi.
#
# Use list comprehension to create a new list containing only the elements of L that are greater than the average of L.

# %%
roll_no = 1024160118
roll_no_str = str(roll_no)
L = [int(digit) * 10 for digit in roll_no_str]

L
# Out:
# [10, 0, 20, 40, 10, 60, 0, 10, 10, 80]

# %%
L.append(50)
print(L)

L.insert(2, 75)
print(L)
# Out:
# [10, 0, 20, 40, 10, 60, 0, 10, 10, 80, 50]
# [10, 0, 75, 20, 40, 10, 60, 0, 10, 10, 80, 50]

# %%
if 10 in L:
    L.remove(10)
    print(L)
else:
    print("10 not present", L)

if len(L) > 3:
    popped_element = L.pop(3)
    print(L)
else:
    print("No change", L)
# Out:
# [0, 75, 20, 40, 10, 60, 0, 10, 10, 80, 50]
# [0, 75, 20, 10, 60, 0, 10, 10, 80, 50]

# %%
L.sort()
print(L)

L.sort(reverse=True)
print(L)
# Out:
# [0, 0, 10, 10, 10, 20, 50, 60, 75, 80]
# [80, 75, 60, 50, 20, 10, 10, 10, 0, 0]

# %%
print("first 3 ", L[:3])
print("last 3", L[-3:])
# Out:
# first 3  [80, 75, 60]
# last 3 [10, 0, 0]

# %%
average_L = sum(L) / len(L)
print(average_L)


L_greater_than_average = [x for x in L if x > average_L]
print("new", L_greater_than_average)
# Out:
# 31.5
# new [80, 75, 60, 50]

# %% [markdown]
# 24.5
# new [75, 60, 50]
# Create a tuple named scores containing 8 marks: use the first 8 values from your list L in Q1.
#
# Find the highest score and its index in the tuple, and the lowest score and how many times it appears.
#
# Reverse the tuple and return the result as a list (tuples themselves cannot be reversed in place — explain why in a one-line comment, referring to tuple immutability).
#
# Ask the user to input a score. Print its first occurrence index if present in the tuple, or a not present message if not.
#
# Attempt to change one element of the tuple directly (e.g., scores[0] = 100). Run it, capture the error Python raises, and explain in one line why this happens and how it differs from a list.
#
# Unpack the tuple into a first score, a second score, and all remaining scores using the * operator in a single line of unpacking.

# %%
scores = tuple(L[:8])
print("Tuple 'scores':", scores)
# Out:
# Tuple 'scores': (80, 75, 60, 50, 20, 10, 10, 10)

# %%
highest_score = max(scores)
highest_score_index = scores.index(highest_score)
print(f"Highest score: {highest_score}, Index of highest score: {highest_score_index}")

lowest_score = min(scores)
lowest_score_count = scores.count(lowest_score)
print(f"Lowest score: {lowest_score}, Count of lowest score: {lowest_score_count}")
# Out:
# Highest score: 80, Index of highest score: 0
# Lowest score: 10, Count of lowest score: 3

# %%
reversed_scores_list = list(reversed(scores))
print("Reversed scores as a list:", reversed_scores_list)
# Out:
# Reversed scores as a list: [10, 10, 10, 20, 50, 60, 75, 80]

# %%
user_input_score = int(input("Please enter a score to search for: "))

if user_input_score in scores:
    try:
        index_of_score = scores.index(user_input_score)
        print(f"The score {user_input_score} is present at index: {index_of_score}")
    except ValueError:
        print(f"The score {user_input_score} is not found in the tuple.")
else:
    print(f"The score {user_input_score} is not present in the tuple.")
# Out:
# Please enter a score to search for: 60
# The score 60 is present at index: 2

# %%
try:
    scores[0] = 100
except TypeError as e:
    print(f"Error attempting to modify tuple: {e}")
# Out:
# Error attempting to modify tuple: 'tuple' object does not support item assignment

# %%
first_score, second_score, *remaining_scores = scores

print(f"First score: {first_score}")
print(f"Second score: {second_score}")
print(f"Remaining scores: {remaining_scores}")
# Out:
# First score: 80
# Second score: 75
# Remaining scores: [60, 50, 20, 10, 10, 10]

# %% [markdown]
# Set the random seed to your own roll number using random.seed(your_roll_number) before generating your numbers — this keeps your list random-looking but reproducible and unique to you (a different seed produces a different list, so this cannot be copied from a classmate).
#
# Generate a list of 100 random numbers between 100 and 900 (inclusive). Count and print all odd numbers in the list.
#
# Count and print all even numbers in the list.
#
# Count and print all prime numbers in the list, and additionally build the actual list of prime numbers found using list comprehension.
#
# Print the number that occurs most frequently in your list, and how many times it occurs.

# %%
import random
from collections import Counter

random.seed(roll_no)
print(f"Random seed set to: {roll_no}")

random_numbers = [random.randint(100, 900) for _ in range(100)]
print("Generated list of 100 random numbers (first 10 shown):", random_numbers[:10])
# Out:
# Random seed set to: 1024160118
# Generated list of 100 random numbers (first 10 shown): [609, 578, 813, 551, 462, 299, 867, 136, 187, 815]

# %%
odd_numbers_count = sum(1 for num in random_numbers if num % 2 != 0)
print(f"Count of odd numbers: {odd_numbers_count}")

even_numbers_count = sum(1 for num in random_numbers if num % 2 == 0)
print(f"Count of even numbers: {even_numbers_count}")
# Out:
# Count of odd numbers: 50
# Count of even numbers: 50

# %%
def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

prime_numbers_list = [num for num in random_numbers if is_prime(num)]
prime_numbers_count = len(prime_numbers_list)

print(f"Count of prime numbers: {prime_numbers_count}")
print("List of prime numbers found:", prime_numbers_list)
# Out:
# Count of prime numbers: 16
# List of prime numbers found: [751, 179, 373, 181, 331, 439, 193, 373, 419, 397, 467, 467, 643, 263, 883, 571]

# %%
if random_numbers:
    number_counts = Counter(random_numbers)
    most_common_number, frequency = number_counts.most_common(1)[0]
    print(f"The most frequent number is: {most_common_number}, which occurs {frequency} times.")
else:
    print("The list of random numbers is empty.")
# Out:
# The most frequent number is: 824, which occurs 2 times.

# %% [markdown]
# Using the same 8 digits of your roll number from Q1 (before multiplying by 10), create set A = {digit × 7 for each digit} and set B = {digit × 9 for each digit}. Print both sets.
#
# Find the union of A and B — all unique values across both sets.
#
# Find the intersection of A and B — values common to both.
#
# Find A − B and B − A separately (not combined) using difference(), and explain in one line how this differs from symmetric_difference().
#
# Find the symmetric difference of A and B.
#
# Check whether A is a subset of B, and whether B is a superset of A, using issubset() and issuperset().
#
# Ask the user to input a value X. Remove X from set A if present using discard() (not remove()) — explain in one line why discard() is safer than remove() when you're not sure the value exists.

# %%
roll_no_digits = [int(digit) for digit in str(roll_no)[:8]]

A = {digit * 7 for digit in roll_no_digits}
B = {digit * 9 for digit in roll_no_digits}

print("Set A:", A)
print("Set B:", B)
# Out:
# Set A: {0, 7, 42, 14, 28}
# Set B: {0, 36, 9, 18, 54}

# %%
union_AB = A.union(B)
print("Union of A and B (A | B):", union_AB)
# Out:
# Union of A and B (A | B): {0, 36, 7, 9, 42, 14, 18, 54, 28}

# %%
intersection_AB = A.intersection(B)
print("Intersection of A and B (A & B):", intersection_AB)
# Out:
# Intersection of A and B (A & B): {0}

# %%
difference_A_B = A.difference(B)
difference_B_A = B.difference(A)

print("A - B (elements in A but not in B):", difference_A_B)
print("B - A (elements in B but not in A):", difference_B_A)
# Out:
# A - B (elements in A but not in B): {42, 28, 14, 7}
# B - A (elements in B but not in A): {9, 18, 36, 54}

# %%
symmetric_difference_AB = A.symmetric_difference(B)
print("Symmetric Difference of A and B (A ^ B):", symmetric_difference_AB)
# Out:
# Symmetric Difference of A and B (A ^ B): {7, 9, 14, 18, 28, 36, 42, 54}

# %%
is_A_subset_B = A.issubset(B)
is_B_superset_A = B.issuperset(A)

print(f"Is A a subset of B?: {is_A_subset_B}")
print(f"Is B a superset of A?: {is_B_superset_A}")
# Out:
# Is A a subset of B?: False
# Is B a superset of A?: False

# %%
x_value = int(input("Please enter a value X to attempt to remove from set A: "))

print(f"Set A before discard({x_value}):", A)
A.discard(x_value)
print(f"Set A after discard({x_value}):", A)
# Out:
# Please enter a value X to attempt to remove from set A: 9
# Set A before discard(9): {0, 42, 14, 28}
# Set A after discard(9): {0, 42, 14, 28}

# %% [markdown]
# Consider the following dictionary:
# my_dict = { "name": "", "roll_no": "", "branch": "", "age": , "city": "" }
#
# Rename the key “city” to “location” without changing its value (do not just recreate the dictionary by hand — use pop() or dictionary comprehension so the code would work for any dictionary).
#
# Add a new key “cgpa” with your CGPA as its value.
#
# Update the value of “age” by increasing it by 1.
#
# Delete the “branch” key using two different methods in two separate copies of the dictionary: once with pop() and once with the del keyword. Explain in one line how pop() differs from del (hint: what does each return?).
#
# Iterate over your dictionary using .items() and print each key-value pair as “key → value”.
#
# Before accessing a key called “email” (which doesn't exist in your dictionary), check for its existence using the in keyword and print a safe fallback message instead of letting the program crash.
#
# Create a second dictionary friend_dict with the same 5 original keys but a friend's (fictional) details. Merge it with your own using the {**dict1, **dict2} syntax, and explain in one line which values “win” when both dictionaries share a key.
#
# Use dictionary comprehension to create a new dictionary containing only the key-value pairs from your original dictionary where the value is a string.

# %%
# Original dictionary
my_dict = {
    "name": "Ayush Kamboj",
    "roll_no": "1024160118",
    "branch": "CSE",
    "age": 20,
    "city": "Gurgaon"
}

# 1. Rename "city" to "location" using pop()
my_dict["location"] = my_dict.pop("city")

# 2. Add CGPA
my_dict["cgpa"] = 9.0

# 3. Increase age by 1
my_dict["age"] += 1

print("Updated dictionary:")
print(my_dict)


# 4. Delete "branch" using pop() in one copy
dict_pop = my_dict.copy()
removed_value = dict_pop.pop("branch")

print("\nUsing pop():")
print(dict_pop)
print("Removed value:", removed_value)


# Delete "branch" using del in another copy
dict_del = my_dict.copy()
del dict_del["branch"]

print("\nUsing del:")
print(dict_del)

# Difference:
# pop() removes the key and returns its value,
# while del removes the key but does not return its value.


# 5. Iterate using .items()
print("\nKey-value pairs:")
for key, value in my_dict.items():
    print(f"{key} → {value}")


# 6. Check if "email" exists before accessing it
print("\nChecking for email:")
if "email" in my_dict:
    print("Email:", my_dict["email"])
else:
    print("Email not found.")


# 7. Friend's dictionary with the same 5 original keys
friend_dict = {
    "name": "Rahul",
    "roll_no": "1024160120",
    "branch": "ECE",
    "age": 21,
    "city": "Delhi"
}

# Merge dictionaries using ** syntax
merged_dict = {**my_dict, **friend_dict}

print("\nMerged dictionary:")
print(merged_dict)

# When both dictionaries have the same key,
# the value from the SECOND dictionary wins.


# 8. Dictionary comprehension for string values only
string_values = {
    key: value
    for key, value in my_dict.items()
    if isinstance(value, str)
}

print("\nDictionary containing only string values:")
print(string_values)
# Out:
# Updated dictionary:
# {'name': 'Ayush Kamboj', 'roll_no': '1024160118', 'branch': 'CSE', 'age': 21, 'location': 'Gurgaon', 'cgpa': 9.0}
#
# Using pop():
# {'name': 'Ayush Kamboj', 'roll_no': '1024160118', 'age': 21, 'location': 'Gurgaon', 'cgpa': 9.0}
# Removed value: CSE
#
# Using del:
# {'name': 'Ayush Kamboj', 'roll_no': '1024160118', 'age': 21, 'location': 'Gurgaon', 'cgpa': 9.0}
#
# Key-value pairs:
# name → Ayush Kamboj
# roll_no → 1024160118
# branch → CSE
# age → 21
# location → Gurgaon
# cgpa → 9.0
#
# Checking for email:
# Email not found.
#
# Merged dictionary:
# {'name': 'Rahul', 'roll_no': '1024160120', 'branch': 'ECE', 'age': 21, 'location': 'Gurgaon', 'cgpa': 9.0, 'city': 'Delhi'}
#
# Dictionary containing only string values:
# {'name': 'Ayush Kamboj', 'roll_no': '1024160118', 'branch': 'CSE', 'location': 'Gurgaon'}
